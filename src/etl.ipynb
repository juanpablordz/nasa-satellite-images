# %% [markdown]
# **Dependencies**

# %%
# standard libraries
import glob, os
import datetime

# third party
import gdal
import pandas as pd
import numpy as np

# local
from data_proccesing_utils import (
    load_data,
    read_dataset,
    find_latitude_position,
    find_longitude_position,
    create_list,
    find_product_value,
    get_julian_date,
    get_year,
    get_month,
    get_day,
    jdtodatestd   
)

# %% [markdown]
# **Change to directory**

# %%
# change to data directory
os.chdir("../data/raw")

# %% [markdown]
# **Process HDF files**

# %%
values_land_and_ocean = []
file_names = []
latitude = []
longitude = []
errors = []

# dataset to extract
SUBDATASET_NAME = "Optical_Depth_Land_And_Ocean (16-bit integer)"

for file in glob.glob('*.hdf'):
    try:
        FILEPATH = file
        land_and_ocean, lat, lon = create_list(SUBDATASET_NAME, 20.5874, -100.3949, FILEPATH)
        print("Data collected for: " + str(lat) + " N (20.5874 N) and " + str(lon) + " E.(-100.3949)")
        file_names.append(file)
        values_land_and_ocean.append(land_and_ocean)
        latitude.append(lat)
        longitude.append(lon)
    except:
        errors.append(file)
# Out:
# Data collected for: 20.586946 N (20.5874 N) and -100.38291 E.(-100.3949)
# Data collected for: 20.586254 N (20.5874 N) and -100.40908 E.(-100.3949)
# Data collected for: 20.587759 N (20.5874 N) and -100.39133 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586784 N (20.5874 N) and -100.368225 E.(-100.3949)
# Data collected for: 20.587906 N (20.5874 N) and -100.398636 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587168 N (20.5874 N) and -100.40928 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586937 N (20.5874 N) and -100.38783 E.(-100.3949)
# Data collected for: 20.588358 N (20.5874 N) and -100.375534 E.(-100.3949)
# Data collected for: 20.586843 N (20.5874 N) and -100.384094 E.(-100.3949)
# Data collected for: 20.587482 N (20.5874 N) and -100.366104 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586973 N (20.5874 N) and -100.38032 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587814 N (20.5874 N) and -100.40432 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587456 N (20.5874 N) and -100.37774 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586166 N (20.5874 N) and -100.382126 E.(-100.3949)
# Data collected for: 20.586018 N (20.5874 N) and -100.43213 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588303 N (20.5874 N) and -100.403145 E.(-100.3949)
# Data collected for: 20.586334 N (20.5874 N) and -100.38357 E.(-100.3949)
# Data collected for: 20.589085 N (20.5874 N) and -100.37302 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586866 N (20.5874 N) and -100.40467 E.(-100.3949)
# Data collected for: 20.587559 N (20.5874 N) and -100.410385 E.(-100.3949)
# Data collected for: 20.586397 N (20.5874 N) and -100.38419 E.(-100.3949)
# Data collected for: 20.588303 N (20.5874 N) and -100.40506 E.(-100.3949)
# Data collected for: 20.58805 N (20.5874 N) and -100.38101 E.(-100.3949)
# Data collected for: 20.58842 N (20.5874 N) and -100.42644 E.(-100.3949)
# Data collected for: 20.58735 N (20.5874 N) and -100.40675 E.(-100.3949)
# Data collected for: 20.58756 N (20.5874 N) and -100.3908 E.(-100.3949)
# Data collected for: 20.587889 N (20.5874 N) and -100.38383 E.(-100.3949)
# Data collected for: 20.587336 N (20.5874 N) and -100.39619 E.(-100.3949)
# Data collected for: 20.588675 N (20.5874 N) and -100.40056 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587341 N (20.5874 N) and -100.39835 E.(-100.3949)
# Data collected for: 20.586493 N (20.5874 N) and -100.38474 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588242 N (20.5874 N) and -100.389465 E.(-100.3949)
# Data collected for: 20.587393 N (20.5874 N) and -100.40849 E.(-100.3949)
# Data collected for: 20.587273 N (20.5874 N) and -100.38966 E.(-100.3949)
# Data collected for: 20.586699 N (20.5874 N) and -100.41865 E.(-100.3949)
# Data collected for: 20.588371 N (20.5874 N) and -100.38388 E.(-100.3949)
# Data collected for: 20.58791 N (20.5874 N) and -100.36246 E.(-100.3949)
# Data collected for: 20.586748 N (20.5874 N) and -100.37693 E.(-100.3949)
# Data collected for: 20.587399 N (20.5874 N) and -100.400986 E.(-100.3949)
# Data collected for: 20.587101 N (20.5874 N) and -100.405304 E.(-100.3949)
# Data collected for: 20.587767 N (20.5874 N) and -100.3699 E.(-100.3949)
# Data collected for: 20.588425 N (20.5874 N) and -100.4034 E.(-100.3949)
# Data collected for: 20.587446 N (20.5874 N) and -100.39918 E.(-100.3949)
# Data collected for: 20.587778 N (20.5874 N) and -100.399826 E.(-100.3949)
# Data collected for: 20.587254 N (20.5874 N) and -100.40918 E.(-100.3949)
# Data collected for: 20.586655 N (20.5874 N) and -100.412315 E.(-100.3949)
# Data collected for: 20.587626 N (20.5874 N) and -100.38812 E.(-100.3949)
# Data collected for: 20.58772 N (20.5874 N) and -100.38907 E.(-100.3949)
# Data collected for: 20.587376 N (20.5874 N) and -100.39201 E.(-100.3949)
# Data collected for: 20.589277 N (20.5874 N) and -100.39128 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588703 N (20.5874 N) and -100.40211 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586102 N (20.5874 N) and -100.38104 E.(-100.3949)
# Data collected for: 20.588753 N (20.5874 N) and -100.35502 E.(-100.3949)
# Data collected for: 20.587294 N (20.5874 N) and -100.4012 E.(-100.3949)
# Data collected for: 20.587482 N (20.5874 N) and -100.38756 E.(-100.3949)
# Data collected for: 20.587305 N (20.5874 N) and -100.386345 E.(-100.3949)
# Data collected for: 20.587294 N (20.5874 N) and -100.390854 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587976 N (20.5874 N) and -100.37366 E.(-100.3949)
# Data collected for: 20.587393 N (20.5874 N) and -100.392395 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58733 N (20.5874 N) and -100.39402 E.(-100.3949)
# Data collected for: 20.590076 N (20.5874 N) and -100.35517 E.(-100.3949)
# Data collected for: 20.587433 N (20.5874 N) and -100.38327 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586718 N (20.5874 N) and -100.43452 E.(-100.3949)
# Data collected for: 20.586817 N (20.5874 N) and -100.39324 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58698 N (20.5874 N) and -100.39464 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.589895 N (20.5874 N) and -100.40022 E.(-100.3949)
# Data collected for: 20.58741 N (20.5874 N) and -100.3985 E.(-100.3949)
# Data collected for: 20.588066 N (20.5874 N) and -100.370926 E.(-100.3949)
# Data collected for: 20.586927 N (20.5874 N) and -100.37688 E.(-100.3949)
# Data collected for: 20.587772 N (20.5874 N) and -100.38993 E.(-100.3949)
# Data collected for: 20.587515 N (20.5874 N) and -100.406265 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587425 N (20.5874 N) and -100.39093 E.(-100.3949)
# Data collected for: 20.586033 N (20.5874 N) and -100.41631 E.(-100.3949)
# Data collected for: 20.586872 N (20.5874 N) and -100.38733 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587961 N (20.5874 N) and -100.43323 E.(-100.3949)
# Data collected for: 20.587542 N (20.5874 N) and -100.36643 E.(-100.3949)
# Data collected for: 20.587214 N (20.5874 N) and -100.41192 E.(-100.3949)
# Data collected for: 20.586985 N (20.5874 N) and -100.391785 E.(-100.3949)
# Data collected for: 20.587849 N (20.5874 N) and -100.39858 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58758 N (20.5874 N) and -100.38249 E.(-100.3949)
# Data collected for: 20.586111 N (20.5874 N) and -100.369995 E.(-100.3949)
# Data collected for: 20.587116 N (20.5874 N) and -100.380615 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58742 N (20.5874 N) and -100.41821 E.(-100.3949)
# Data collected for: 20.587519 N (20.5874 N) and -100.408325 E.(-100.3949)
# Data collected for: 20.58642 N (20.5874 N) and -100.42356 E.(-100.3949)
# Data collected for: 20.590359 N (20.5874 N) and -100.376114 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587324 N (20.5874 N) and -100.40943 E.(-100.3949)
# Data collected for: 20.588144 N (20.5874 N) and -100.40493 E.(-100.3949)
# Data collected for: 20.588995 N (20.5874 N) and -100.41929 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58718 N (20.5874 N) and -100.38736 E.(-100.3949)
# Data collected for: 20.587175 N (20.5874 N) and -100.38777 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587482 N (20.5874 N) and -100.361084 E.(-100.3949)
# Data collected for: 20.586687 N (20.5874 N) and -100.40814 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588776 N (20.5874 N) and -100.39331 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588005 N (20.5874 N) and -100.37845 E.(-100.3949)
# Data collected for: 20.588755 N (20.5874 N) and -100.38742 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586874 N (20.5874 N) and -100.38204 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.590185 N (20.5874 N) and -100.39591 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587502 N (20.5874 N) and -100.38077 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587193 N (20.5874 N) and -100.351166 E.(-100.3949)
# Data collected for: 20.587755 N (20.5874 N) and -100.387245 E.(-100.3949)
# Data collected for: 20.587873 N (20.5874 N) and -100.3937 E.(-100.3949)
# Data collected for: 20.587566 N (20.5874 N) and -100.40102 E.(-100.3949)
# Data collected for: 20.587805 N (20.5874 N) and -100.40803 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588161 N (20.5874 N) and -100.38868 E.(-100.3949)
# Data collected for: 20.586193 N (20.5874 N) and -100.41293 E.(-100.3949)
# Data collected for: 20.588099 N (20.5874 N) and -100.411514 E.(-100.3949)
# Data collected for: 20.587698 N (20.5874 N) and -100.38831 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587097 N (20.5874 N) and -100.38149 E.(-100.3949)
# Data collected for: 20.587465 N (20.5874 N) and -100.38965 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586973 N (20.5874 N) and -100.395096 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58761 N (20.5874 N) and -100.38771 E.(-100.3949)
# Data collected for: 20.58665 N (20.5874 N) and -100.43861 E.(-100.3949)
# Data collected for: 20.587704 N (20.5874 N) and -100.38473 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586815 N (20.5874 N) and -100.41602 E.(-100.3949)
# Data collected for: 20.5874 N (20.5874 N) and -100.41448 E.(-100.3949)
# Data collected for: 20.586693 N (20.5874 N) and -100.38168 E.(-100.3949)
# Data collected for: 20.587523 N (20.5874 N) and -100.39004 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587664 N (20.5874 N) and -100.41718 E.(-100.3949)
# Data collected for: 20.587318 N (20.5874 N) and -100.42129 E.(-100.3949)
# Data collected for: 20.589203 N (20.5874 N) and -100.4276 E.(-100.3949)
# Data collected for: 20.587399 N (20.5874 N) and -100.393906 E.(-100.3949)
# Data collected for: 20.587807 N (20.5874 N) and -100.4198 E.(-100.3949)
# Data collected for: 20.58769 N (20.5874 N) and -100.38887 E.(-100.3949)
# Data collected for: 20.58768 N (20.5874 N) and -100.38674 E.(-100.3949)
# Data collected for: 20.58732 N (20.5874 N) and -100.4173 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586887 N (20.5874 N) and -100.413605 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586704 N (20.5874 N) and -100.394264 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.589302 N (20.5874 N) and -100.38056 E.(-100.3949)
# Data collected for: 20.587532 N (20.5874 N) and -100.39008 E.(-100.3949)
# Data collected for: 20.587477 N (20.5874 N) and -100.39348 E.(-100.3949)
# Data collected for: 20.587809 N (20.5874 N) and -100.391235 E.(-100.3949)
# Data collected for: 20.587109 N (20.5874 N) and -100.39902 E.(-100.3949)
# Data collected for: 20.586922 N (20.5874 N) and -100.41391 E.(-100.3949)
# Data collected for: 20.5873 N (20.5874 N) and -100.40586 E.(-100.3949)
# Data collected for: 20.587875 N (20.5874 N) and -100.381615 E.(-100.3949)
# Data collected for: 20.587917 N (20.5874 N) and -100.41021 E.(-100.3949)
# Data collected for: 20.587029 N (20.5874 N) and -100.4027 E.(-100.3949)
# Data collected for: 20.587196 N (20.5874 N) and -100.37107 E.(-100.3949)
# Data collected for: 20.587658 N (20.5874 N) and -100.37501 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588379 N (20.5874 N) and -100.37588 E.(-100.3949)
# Data collected for: 20.58724 N (20.5874 N) and -100.38422 E.(-100.3949)
# Data collected for: 20.58729 N (20.5874 N) and -100.40548 E.(-100.3949)
# Data collected for: 20.587793 N (20.5874 N) and -100.36684 E.(-100.3949)
# Data collected for: 20.587933 N (20.5874 N) and -100.40917 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.589485 N (20.5874 N) and -100.36826 E.(-100.3949)
# Data collected for: 20.588188 N (20.5874 N) and -100.3576 E.(-100.3949)
# Data collected for: 20.58954 N (20.5874 N) and -100.37837 E.(-100.3949)
# Data collected for: 20.5869 N (20.5874 N) and -100.39044 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586674 N (20.5874 N) and -100.377 E.(-100.3949)
# Data collected for: 20.58734 N (20.5874 N) and -100.40585 E.(-100.3949)
# Data collected for: 20.587055 N (20.5874 N) and -100.41083 E.(-100.3949)
# Data collected for: 20.58673 N (20.5874 N) and -100.434006 E.(-100.3949)
# Data collected for: 20.585981 N (20.5874 N) and -100.433426 E.(-100.3949)
# Data collected for: 20.58705 N (20.5874 N) and -100.39811 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586645 N (20.5874 N) and -100.40829 E.(-100.3949)
# Data collected for: 20.587568 N (20.5874 N) and -100.40618 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588095 N (20.5874 N) and -100.37563 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58719 N (20.5874 N) and -100.40326 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587025 N (20.5874 N) and -100.385735 E.(-100.3949)
# Data collected for: 20.586615 N (20.5874 N) and -100.413475 E.(-100.3949)
# Data collected for: 20.585464 N (20.5874 N) and -100.3498 E.(-100.3949)
# Data collected for: 20.587746 N (20.5874 N) and -100.40663 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586824 N (20.5874 N) and -100.38012 E.(-100.3949)
# Data collected for: 20.586618 N (20.5874 N) and -100.38859 E.(-100.3949)
# Data collected for: 20.588005 N (20.5874 N) and -100.397675 E.(-100.3949)
# Data collected for: 20.587164 N (20.5874 N) and -100.381744 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586687 N (20.5874 N) and -100.41931 E.(-100.3949)
# Data collected for: 20.587145 N (20.5874 N) and -100.407745 E.(-100.3949)
# Data collected for: 20.587685 N (20.5874 N) and -100.391045 E.(-100.3949)
# Data collected for: 20.587606 N (20.5874 N) and -100.395424 E.(-100.3949)
# Data collected for: 20.586695 N (20.5874 N) and -100.37736 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588152 N (20.5874 N) and -100.371025 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586666 N (20.5874 N) and -100.37255 E.(-100.3949)
# Data collected for: 20.58736 N (20.5874 N) and -100.38775 E.(-100.3949)
# Data collected for: 20.586794 N (20.5874 N) and -100.40173 E.(-100.3949)
# Data collected for: 20.587772 N (20.5874 N) and -100.37421 E.(-100.3949)
# Data collected for: 20.588161 N (20.5874 N) and -100.37406 E.(-100.3949)
# Data collected for: 20.5883 N (20.5874 N) and -100.40179 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587069 N (20.5874 N) and -100.40487 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586655 N (20.5874 N) and -100.37439 E.(-100.3949)
# Data collected for: 20.588371 N (20.5874 N) and -100.39047 E.(-100.3949)
# Data collected for: 20.587244 N (20.5874 N) and -100.38614 E.(-100.3949)
# Data collected for: 20.587978 N (20.5874 N) and -100.37954 E.(-100.3949)
# Data collected for: 20.587599 N (20.5874 N) and -100.38172 E.(-100.3949)
# Data collected for: 20.587563 N (20.5874 N) and -100.42077 E.(-100.3949)
# Data collected for: 20.587969 N (20.5874 N) and -100.389404 E.(-100.3949)
# Data collected for: 20.587336 N (20.5874 N) and -100.38546 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587994 N (20.5874 N) and -100.3721 E.(-100.3949)
# Data collected for: 20.58784 N (20.5874 N) and -100.40896 E.(-100.3949)
# Data collected for: 20.586916 N (20.5874 N) and -100.412544 E.(-100.3949)
# Data collected for: 20.58713 N (20.5874 N) and -100.374 E.(-100.3949)
# Data collected for: 20.587044 N (20.5874 N) and -100.42823 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588718 N (20.5874 N) and -100.38354 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58714 N (20.5874 N) and -100.39581 E.(-100.3949)
# Data collected for: 20.588139 N (20.5874 N) and -100.41099 E.(-100.3949)
# Data collected for: 20.588896 N (20.5874 N) and -100.37061 E.(-100.3949)
# Data collected for: 20.592216 N (20.5874 N) and -100.437035 E.(-100.3949)
# Data collected for: 20.587404 N (20.5874 N) and -100.41598 E.(-100.3949)
# Data collected for: 20.586576 N (20.5874 N) and -100.41015 E.(-100.3949)
# Data collected for: 20.587896 N (20.5874 N) and -100.40048 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588646 N (20.5874 N) and -100.39708 E.(-100.3949)
# Data collected for: 20.58936 N (20.5874 N) and -100.39688 E.(-100.3949)
# Data collected for: 20.58946 N (20.5874 N) and -100.36937 E.(-100.3949)
# Data collected for: 20.587809 N (20.5874 N) and -100.402016 E.(-100.3949)
# Data collected for: 20.587404 N (20.5874 N) and -100.402626 E.(-100.3949)
# Data collected for: 20.587566 N (20.5874 N) and -100.39334 E.(-100.3949)
# Data collected for: 20.587837 N (20.5874 N) and -100.3931 E.(-100.3949)
# Data collected for: 20.586813 N (20.5874 N) and -100.35545 E.(-100.3949)
# Data collected for: 20.587067 N (20.5874 N) and -100.39429 E.(-100.3949)
# Data collected for: 20.587732 N (20.5874 N) and -100.40998 E.(-100.3949)
# Data collected for: 20.587305 N (20.5874 N) and -100.38871 E.(-100.3949)
# Data collected for: 20.587542 N (20.5874 N) and -100.38757 E.(-100.3949)
# Data collected for: 20.586966 N (20.5874 N) and -100.3809 E.(-100.3949)
# Data collected for: 20.588026 N (20.5874 N) and -100.403824 E.(-100.3949)
# Data collected for: 20.58635 N (20.5874 N) and -100.39558 E.(-100.3949)
# Data collected for: 20.58773 N (20.5874 N) and -100.41802 E.(-100.3949)
# Data collected for: 20.589258 N (20.5874 N) and -100.422874 E.(-100.3949)
# Data collected for: 20.587276 N (20.5874 N) and -100.42401 E.(-100.3949)
# Data collected for: 20.587994 N (20.5874 N) and -100.38899 E.(-100.3949)
# Data collected for: 20.587162 N (20.5874 N) and -100.3811 E.(-100.3949)
# Data collected for: 20.587172 N (20.5874 N) and -100.4297 E.(-100.3949)
# Data collected for: 20.58745 N (20.5874 N) and -100.37877 E.(-100.3949)
# Data collected for: 20.587952 N (20.5874 N) and -100.37173 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587477 N (20.5874 N) and -100.40518 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.590143 N (20.5874 N) and -100.35807 E.(-100.3949)
# Data collected for: 20.586641 N (20.5874 N) and -100.38357 E.(-100.3949)
# Data collected for: 20.58737 N (20.5874 N) and -100.40692 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588066 N (20.5874 N) and -100.40322 E.(-100.3949)
# Data collected for: 20.588936 N (20.5874 N) and -100.36575 E.(-100.3949)
# Data collected for: 20.587025 N (20.5874 N) and -100.40471 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586794 N (20.5874 N) and -100.38379 E.(-100.3949)
# Data collected for: 20.587423 N (20.5874 N) and -100.40428 E.(-100.3949)
# Data collected for: 20.587793 N (20.5874 N) and -100.39337 E.(-100.3949)
# Data collected for: 20.5873 N (20.5874 N) and -100.41002 E.(-100.3949)
# Data collected for: 20.588161 N (20.5874 N) and -100.450096 E.(-100.3949)
# Data collected for: 20.58756 N (20.5874 N) and -100.391335 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587088 N (20.5874 N) and -100.38105 E.(-100.3949)
# Data collected for: 20.587269 N (20.5874 N) and -100.37533 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586926 N (20.5874 N) and -100.38246 E.(-100.3949)
# Data collected for: 20.587112 N (20.5874 N) and -100.36604 E.(-100.3949)
# Data collected for: 20.587337 N (20.5874 N) and -100.38826 E.(-100.3949)
# Data collected for: 20.586826 N (20.5874 N) and -100.400665 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586565 N (20.5874 N) and -100.397545 E.(-100.3949)
# Data collected for: 20.587635 N (20.5874 N) and -100.38434 E.(-100.3949)
# Data collected for: 20.589317 N (20.5874 N) and -100.388245 E.(-100.3949)
# Data collected for: 20.587254 N (20.5874 N) and -100.39419 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588789 N (20.5874 N) and -100.39421 E.(-100.3949)
# Data collected for: 20.585974 N (20.5874 N) and -100.35998 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58689 N (20.5874 N) and -100.38945 E.(-100.3949)
# Data collected for: 20.587545 N (20.5874 N) and -100.3784 E.(-100.3949)
# Data collected for: 20.586216 N (20.5874 N) and -100.36925 E.(-100.3949)
# Data collected for: 20.586945 N (20.5874 N) and -100.397385 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.585356 N (20.5874 N) and -100.405334 E.(-100.3949)
# Data collected for: 20.58699 N (20.5874 N) and -100.38299 E.(-100.3949)
# Data collected for: 20.587296 N (20.5874 N) and -100.39683 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588322 N (20.5874 N) and -100.4253 E.(-100.3949)
# Data collected for: 20.587473 N (20.5874 N) and -100.40964 E.(-100.3949)
# Data collected for: 20.587305 N (20.5874 N) and -100.39981 E.(-100.3949)
# Data collected for: 20.589706 N (20.5874 N) and -100.400665 E.(-100.3949)
# Data collected for: 20.587433 N (20.5874 N) and -100.39387 E.(-100.3949)
# Data collected for: 20.587345 N (20.5874 N) and -100.407715 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.5874 N (20.5874 N) and -100.40513 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588741 N (20.5874 N) and -100.3972 E.(-100.3949)
# Data collected for: 20.587772 N (20.5874 N) and -100.402534 E.(-100.3949)
# Data collected for: 20.58421 N (20.5874 N) and -100.41004 E.(-100.3949)
# Data collected for: 20.586735 N (20.5874 N) and -100.392845 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587381 N (20.5874 N) and -100.4171 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.589487 N (20.5874 N) and -100.36985 E.(-100.3949)
# Data collected for: 20.587261 N (20.5874 N) and -100.44225 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586872 N (20.5874 N) and -100.40018 E.(-100.3949)
# Data collected for: 20.587543 N (20.5874 N) and -100.42346 E.(-100.3949)
# Data collected for: 20.587461 N (20.5874 N) and -100.423546 E.(-100.3949)
# Data collected for: 20.585768 N (20.5874 N) and -100.402336 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587687 N (20.5874 N) and -100.385185 E.(-100.3949)
# Data collected for: 20.587944 N (20.5874 N) and -100.40145 E.(-100.3949)
# Data collected for: 20.589123 N (20.5874 N) and -100.4008 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58761 N (20.5874 N) and -100.385925 E.(-100.3949)
# Data collected for: 20.586739 N (20.5874 N) and -100.389206 E.(-100.3949)
# Data collected for: 20.587389 N (20.5874 N) and -100.40142 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588337 N (20.5874 N) and -100.388565 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587088 N (20.5874 N) and -100.39907 E.(-100.3949)
# Data collected for: 20.587198 N (20.5874 N) and -100.40236 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587053 N (20.5874 N) and -100.40354 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587696 N (20.5874 N) and -100.426605 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586527 N (20.5874 N) and -100.38202 E.(-100.3949)
# Data collected for: 20.58858 N (20.5874 N) and -100.38424 E.(-100.3949)
# Data collected for: 20.58776 N (20.5874 N) and -100.39413 E.(-100.3949)
# Data collected for: 20.58758 N (20.5874 N) and -100.382095 E.(-100.3949)
# Data collected for: 20.587166 N (20.5874 N) and -100.382034 E.(-100.3949)
# Data collected for: 20.587767 N (20.5874 N) and -100.38591 E.(-100.3949)
# Data collected for: 20.585583 N (20.5874 N) and -100.40567 E.(-100.3949)
# Data collected for: 20.585697 N (20.5874 N) and -100.4218 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58856 N (20.5874 N) and -100.43184 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58764 N (20.5874 N) and -100.387184 E.(-100.3949)
# Data collected for: 20.587133 N (20.5874 N) and -100.41211 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587543 N (20.5874 N) and -100.40766 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58874 N (20.5874 N) and -100.37631 E.(-100.3949)
# Data collected for: 20.587526 N (20.5874 N) and -100.39907 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588255 N (20.5874 N) and -100.40736 E.(-100.3949)
# Data collected for: 20.587395 N (20.5874 N) and -100.39902 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587921 N (20.5874 N) and -100.38081 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587557 N (20.5874 N) and -100.397705 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587177 N (20.5874 N) and -100.40749 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58758 N (20.5874 N) and -100.391335 E.(-100.3949)
# Data collected for: 20.587217 N (20.5874 N) and -100.398605 E.(-100.3949)
# Data collected for: 20.58734 N (20.5874 N) and -100.36514 E.(-100.3949)
# Data collected for: 20.587128 N (20.5874 N) and -100.3903 E.(-100.3949)
# Data collected for: 20.587683 N (20.5874 N) and -100.391106 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587605 N (20.5874 N) and -100.40764 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587515 N (20.5874 N) and -100.40993 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587622 N (20.5874 N) and -100.38361 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.585869 N (20.5874 N) and -100.36857 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58787 N (20.5874 N) and -100.40778 E.(-100.3949)
# Data collected for: 20.587187 N (20.5874 N) and -100.396774 E.(-100.3949)
# Data collected for: 20.587303 N (20.5874 N) and -100.38775 E.(-100.3949)
# Data collected for: 20.589157 N (20.5874 N) and -100.35934 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588066 N (20.5874 N) and -100.38419 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587236 N (20.5874 N) and -100.38391 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586096 N (20.5874 N) and -100.37753 E.(-100.3949)
# Data collected for: 20.588554 N (20.5874 N) and -100.42889 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586637 N (20.5874 N) and -100.37716 E.(-100.3949)
# Data collected for: 20.58678 N (20.5874 N) and -100.41334 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587004 N (20.5874 N) and -100.39499 E.(-100.3949)
# Data collected for: 20.58533 N (20.5874 N) and -100.37895 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587269 N (20.5874 N) and -100.40937 E.(-100.3949)
# Data collected for: 20.587715 N (20.5874 N) and -100.38678 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587753 N (20.5874 N) and -100.39442 E.(-100.3949)
# Data collected for: 20.58819 N (20.5874 N) and -100.405685 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587934 N (20.5874 N) and -100.38154 E.(-100.3949)
# Data collected for: 20.586773 N (20.5874 N) and -100.41087 E.(-100.3949)
# Data collected for: 20.586054 N (20.5874 N) and -100.3931 E.(-100.3949)
# Data collected for: 20.587816 N (20.5874 N) and -100.39576 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58674 N (20.5874 N) and -100.37357 E.(-100.3949)
# Data collected for: 20.586493 N (20.5874 N) and -100.40114 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587378 N (20.5874 N) and -100.37762 E.(-100.3949)
# Data collected for: 20.587399 N (20.5874 N) and -100.40423 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58701 N (20.5874 N) and -100.36617 E.(-100.3949)
# Data collected for: 20.587608 N (20.5874 N) and -100.41333 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586048 N (20.5874 N) and -100.419464 E.(-100.3949)
# Data collected for: 20.588179 N (20.5874 N) and -100.372665 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587452 N (20.5874 N) and -100.409294 E.(-100.3949)
# Data collected for: 20.587187 N (20.5874 N) and -100.3818 E.(-100.3949)
# Data collected for: 20.588537 N (20.5874 N) and -100.382256 E.(-100.3949)
# Data collected for: 20.587263 N (20.5874 N) and -100.376335 E.(-100.3949)
# Data collected for: 20.586292 N (20.5874 N) and -100.39977 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.583435 N (20.5874 N) and -100.38639 E.(-100.3949)
# Data collected for: 20.587097 N (20.5874 N) and -100.384796 E.(-100.3949)
# Data collected for: 20.587206 N (20.5874 N) and -100.390755 E.(-100.3949)
# Data collected for: 20.586864 N (20.5874 N) and -100.40954 E.(-100.3949)
# Data collected for: 20.587889 N (20.5874 N) and -100.38338 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588171 N (20.5874 N) and -100.376495 E.(-100.3949)
# Data collected for: 20.587612 N (20.5874 N) and -100.38114 E.(-100.3949)
# Data collected for: 20.587631 N (20.5874 N) and -100.40173 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.585793 N (20.5874 N) and -100.43086 E.(-100.3949)
# Data collected for: 20.587183 N (20.5874 N) and -100.394966 E.(-100.3949)
# Data collected for: 20.587112 N (20.5874 N) and -100.38245 E.(-100.3949)
# Data collected for: 20.586767 N (20.5874 N) and -100.406685 E.(-100.3949)
# Data collected for: 20.583408 N (20.5874 N) and -100.36366 E.(-100.3949)
# Data collected for: 20.587263 N (20.5874 N) and -100.39347 E.(-100.3949)
# Data collected for: 20.587973 N (20.5874 N) and -100.3762 E.(-100.3949)
# Data collected for: 20.5867 N (20.5874 N) and -100.40051 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.584808 N (20.5874 N) and -100.3725 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58583 N (20.5874 N) and -100.390526 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587315 N (20.5874 N) and -100.401505 E.(-100.3949)
# Data collected for: 20.587326 N (20.5874 N) and -100.41584 E.(-100.3949)
# Data collected for: 20.58687 N (20.5874 N) and -100.390045 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587538 N (20.5874 N) and -100.42635 E.(-100.3949)
# Data collected for: 20.58802 N (20.5874 N) and -100.40105 E.(-100.3949)
# Data collected for: 20.587555 N (20.5874 N) and -100.40111 E.(-100.3949)
# Data collected for: 20.585892 N (20.5874 N) and -100.34046 E.(-100.3949)
# Data collected for: 20.587782 N (20.5874 N) and -100.40897 E.(-100.3949)
# Data collected for: 20.587135 N (20.5874 N) and -100.39755 E.(-100.3949)
# Data collected for: 20.590643 N (20.5874 N) and -100.41819 E.(-100.3949)
# Data collected for: 20.586933 N (20.5874 N) and -100.390755 E.(-100.3949)
# Data collected for: 20.586168 N (20.5874 N) and -100.400795 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586966 N (20.5874 N) and -100.367966 E.(-100.3949)
# Data collected for: 20.586617 N (20.5874 N) and -100.39464 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588495 N (20.5874 N) and -100.41704 E.(-100.3949)
# Data collected for: 20.589048 N (20.5874 N) and -100.39968 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587551 N (20.5874 N) and -100.38887 E.(-100.3949)
# Data collected for: 20.58721 N (20.5874 N) and -100.420044 E.(-100.3949)
# Data collected for: 20.58649 N (20.5874 N) and -100.43008 E.(-100.3949)
# Data collected for: 20.587482 N (20.5874 N) and -100.350845 E.(-100.3949)
# Data collected for: 20.587793 N (20.5874 N) and -100.37567 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587217 N (20.5874 N) and -100.39262 E.(-100.3949)
# Data collected for: 20.58753 N (20.5874 N) and -100.37021 E.(-100.3949)
# Data collected for: 20.582993 N (20.5874 N) and -100.4144 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587336 N (20.5874 N) and -100.38052 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588223 N (20.5874 N) and -100.407 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587389 N (20.5874 N) and -100.395096 E.(-100.3949)
# Data collected for: 20.588936 N (20.5874 N) and -100.36477 E.(-100.3949)
# Data collected for: 20.586927 N (20.5874 N) and -100.42068 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587635 N (20.5874 N) and -100.375854 E.(-100.3949)
# Data collected for: 20.588713 N (20.5874 N) and -100.37882 E.(-100.3949)
# Data collected for: 20.590267 N (20.5874 N) and -100.382576 E.(-100.3949)
# Data collected for: 20.587072 N (20.5874 N) and -100.3919 E.(-100.3949)
# Data collected for: 20.587393 N (20.5874 N) and -100.40045 E.(-100.3949)
# Data collected for: 20.587196 N (20.5874 N) and -100.40143 E.(-100.3949)
# Data collected for: 20.586887 N (20.5874 N) and -100.41522 E.(-100.3949)
# Data collected for: 20.587658 N (20.5874 N) and -100.339195 E.(-100.3949)
# Data collected for: 20.586966 N (20.5874 N) and -100.43179 E.(-100.3949)
# Data collected for: 20.589136 N (20.5874 N) and -100.36877 E.(-100.3949)
# Data collected for: 20.586739 N (20.5874 N) and -100.40402 E.(-100.3949)
# Data collected for: 20.58748 N (20.5874 N) and -100.36767 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587414 N (20.5874 N) and -100.38098 E.(-100.3949)
# Data collected for: 20.58709 N (20.5874 N) and -100.422585 E.(-100.3949)
# Data collected for: 20.586771 N (20.5874 N) and -100.39016 E.(-100.3949)
# Data collected for: 20.587654 N (20.5874 N) and -100.40671 E.(-100.3949)
# Data collected for: 20.586412 N (20.5874 N) and -100.4177 E.(-100.3949)
# Data collected for: 20.588982 N (20.5874 N) and -100.41137 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587381 N (20.5874 N) and -100.38881 E.(-100.3949)
# Data collected for: 20.587461 N (20.5874 N) and -100.37772 E.(-100.3949)
# Data collected for: 20.587173 N (20.5874 N) and -100.410904 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588606 N (20.5874 N) and -100.36385 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587088 N (20.5874 N) and -100.36167 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587046 N (20.5874 N) and -100.40903 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587292 N (20.5874 N) and -100.423515 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.5868 N (20.5874 N) and -100.375725 E.(-100.3949)
# Data collected for: 20.58738 N (20.5874 N) and -100.41951 E.(-100.3949)
# Data collected for: 20.587202 N (20.5874 N) and -100.387794 E.(-100.3949)
# Data collected for: 20.587856 N (20.5874 N) and -100.39101 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587322 N (20.5874 N) and -100.387405 E.(-100.3949)
# Data collected for: 20.593094 N (20.5874 N) and -100.398834 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.585775 N (20.5874 N) and -100.407425 E.(-100.3949)
# Data collected for: 20.588196 N (20.5874 N) and -100.38756 E.(-100.3949)
# Data collected for: 20.58374 N (20.5874 N) and -100.35688 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587355 N (20.5874 N) and -100.38174 E.(-100.3949)
# Data collected for: 20.588373 N (20.5874 N) and -100.38989 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587374 N (20.5874 N) and -100.38076 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58825 N (20.5874 N) and -100.40388 E.(-100.3949)
# Data collected for: 20.585363 N (20.5874 N) and -100.349976 E.(-100.3949)
# Data collected for: 20.587645 N (20.5874 N) and -100.39145 E.(-100.3949)
# Data collected for: 20.586826 N (20.5874 N) and -100.38878 E.(-100.3949)
# Data collected for: 20.58622 N (20.5874 N) and -100.383446 E.(-100.3949)
# Data collected for: 20.587652 N (20.5874 N) and -100.3992 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587015 N (20.5874 N) and -100.39312 E.(-100.3949)
# Data collected for: 20.587244 N (20.5874 N) and -100.38225 E.(-100.3949)
# Data collected for: 20.587662 N (20.5874 N) and -100.39133 E.(-100.3949)
# Data collected for: 20.59098 N (20.5874 N) and -100.383194 E.(-100.3949)
# Data collected for: 20.588549 N (20.5874 N) and -100.42821 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587543 N (20.5874 N) and -100.36779 E.(-100.3949)
# Data collected for: 20.58782 N (20.5874 N) and -100.39274 E.(-100.3949)
# Data collected for: 20.587845 N (20.5874 N) and -100.389915 E.(-100.3949)
# Data collected for: 20.587824 N (20.5874 N) and -100.356705 E.(-100.3949)
# Data collected for: 20.58696 N (20.5874 N) and -100.3962 E.(-100.3949)
# Data collected for: 20.587536 N (20.5874 N) and -100.388084 E.(-100.3949)
# Data collected for: 20.587492 N (20.5874 N) and -100.39686 E.(-100.3949)
# Data collected for: 20.587532 N (20.5874 N) and -100.35572 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586847 N (20.5874 N) and -100.4136 E.(-100.3949)
# Data collected for: 20.587242 N (20.5874 N) and -100.39387 E.(-100.3949)
# Data collected for: 20.587406 N (20.5874 N) and -100.40564 E.(-100.3949)
# Data collected for: 20.586975 N (20.5874 N) and -100.392494 E.(-100.3949)
# Data collected for: 20.588856 N (20.5874 N) and -100.4168 E.(-100.3949)
# Data collected for: 20.587149 N (20.5874 N) and -100.361916 E.(-100.3949)
# Data collected for: 20.588043 N (20.5874 N) and -100.40098 E.(-100.3949)
# Data collected for: 20.588423 N (20.5874 N) and -100.37845 E.(-100.3949)
# Data collected for: 20.587133 N (20.5874 N) and -100.39553 E.(-100.3949)
# Data collected for: 20.587852 N (20.5874 N) and -100.374275 E.(-100.3949)
# Data collected for: 20.587505 N (20.5874 N) and -100.40611 E.(-100.3949)
# Data collected for: 20.587822 N (20.5874 N) and -100.38873 E.(-100.3949)
# Data collected for: 20.590174 N (20.5874 N) and -100.41012 E.(-100.3949)
# Data collected for: 20.58696 N (20.5874 N) and -100.4073 E.(-100.3949)
# Data collected for: 20.587292 N (20.5874 N) and -100.41177 E.(-100.3949)
# Data collected for: 20.587343 N (20.5874 N) and -100.38674 E.(-100.3949)
# Data collected for: 20.587652 N (20.5874 N) and -100.427025 E.(-100.3949)
# Data collected for: 20.58774 N (20.5874 N) and -100.393486 E.(-100.3949)
# Data collected for: 20.587976 N (20.5874 N) and -100.385155 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.585636 N (20.5874 N) and -100.44375 E.(-100.3949)
# Data collected for: 20.58665 N (20.5874 N) and -100.393036 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587744 N (20.5874 N) and -100.40137 E.(-100.3949)
# Data collected for: 20.587193 N (20.5874 N) and -100.39663 E.(-100.3949)
# Data collected for: 20.587364 N (20.5874 N) and -100.40074 E.(-100.3949)
# Data collected for: 20.587444 N (20.5874 N) and -100.400215 E.(-100.3949)
# Data collected for: 20.587227 N (20.5874 N) and -100.408424 E.(-100.3949)
# Data collected for: 20.5882 N (20.5874 N) and -100.3829 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587164 N (20.5874 N) and -100.38355 E.(-100.3949)
# Data collected for: 20.586882 N (20.5874 N) and -100.37773 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588936 N (20.5874 N) and -100.36234 E.(-100.3949)
# Data collected for: 20.587883 N (20.5874 N) and -100.40074 E.(-100.3949)
# Data collected for: 20.589113 N (20.5874 N) and -100.41123 E.(-100.3949)
# Data collected for: 20.58721 N (20.5874 N) and -100.40022 E.(-100.3949)
# Data collected for: 20.587093 N (20.5874 N) and -100.40385 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586933 N (20.5874 N) and -100.4083 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587456 N (20.5874 N) and -100.406265 E.(-100.3949)
# Data collected for: 20.587957 N (20.5874 N) and -100.40525 E.(-100.3949)
# Data collected for: 20.587858 N (20.5874 N) and -100.3834 E.(-100.3949)
# Data collected for: 20.587275 N (20.5874 N) and -100.39571 E.(-100.3949)
# Data collected for: 20.586786 N (20.5874 N) and -100.39295 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.589077 N (20.5874 N) and -100.41108 E.(-100.3949)
# Data collected for: 20.587425 N (20.5874 N) and -100.405 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587032 N (20.5874 N) and -100.40756 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587646 N (20.5874 N) and -100.410645 E.(-100.3949)
# Data collected for: 20.587252 N (20.5874 N) and -100.40119 E.(-100.3949)
# Data collected for: 20.587036 N (20.5874 N) and -100.40496 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588219 N (20.5874 N) and -100.40723 E.(-100.3949)
# Data collected for: 20.58608 N (20.5874 N) and -100.38175 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586805 N (20.5874 N) and -100.39803 E.(-100.3949)
# Data collected for: 20.587254 N (20.5874 N) and -100.38997 E.(-100.3949)
# Data collected for: 20.588387 N (20.5874 N) and -100.41269 E.(-100.3949)
# Data collected for: 20.587276 N (20.5874 N) and -100.41106 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588326 N (20.5874 N) and -100.404854 E.(-100.3949)
# Data collected for: 20.58678 N (20.5874 N) and -100.38993 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587423 N (20.5874 N) and -100.395 E.(-100.3949)
# Data collected for: 20.587614 N (20.5874 N) and -100.4075 E.(-100.3949)
# Data collected for: 20.587734 N (20.5874 N) and -100.40617 E.(-100.3949)
# Data collected for: 20.591866 N (20.5874 N) and -100.409065 E.(-100.3949)
# Data collected for: 20.587646 N (20.5874 N) and -100.42765 E.(-100.3949)
# Data collected for: 20.587091 N (20.5874 N) and -100.41037 E.(-100.3949)
# Data collected for: 20.586094 N (20.5874 N) and -100.37808 E.(-100.3949)
# Data collected for: 20.587498 N (20.5874 N) and -100.410736 E.(-100.3949)
# Data collected for: 20.587563 N (20.5874 N) and -100.39738 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587688 N (20.5874 N) and -100.396645 E.(-100.3949)
# Data collected for: 20.587116 N (20.5874 N) and -100.397316 E.(-100.3949)
# Data collected for: 20.583206 N (20.5874 N) and -100.43741 E.(-100.3949)
# Data collected for: 20.58761 N (20.5874 N) and -100.40125 E.(-100.3949)
# Data collected for: 20.587446 N (20.5874 N) and -100.39477 E.(-100.3949)
# Data collected for: 20.587866 N (20.5874 N) and -100.38058 E.(-100.3949)
# Data collected for: 20.592066 N (20.5874 N) and -100.37849 E.(-100.3949)
# Data collected for: 20.587168 N (20.5874 N) and -100.37227 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587042 N (20.5874 N) and -100.3991 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587976 N (20.5874 N) and -100.36772 E.(-100.3949)
# Data collected for: 20.585556 N (20.5874 N) and -100.40291 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586014 N (20.5874 N) and -100.40981 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587679 N (20.5874 N) and -100.38006 E.(-100.3949)
# Data collected for: 20.587353 N (20.5874 N) and -100.38592 E.(-100.3949)
# Data collected for: 20.587275 N (20.5874 N) and -100.37021 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587362 N (20.5874 N) and -100.394516 E.(-100.3949)
# Data collected for: 20.587042 N (20.5874 N) and -100.37745 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588161 N (20.5874 N) and -100.382706 E.(-100.3949)
# Data collected for: 20.586672 N (20.5874 N) and -100.3989 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587566 N (20.5874 N) and -100.408295 E.(-100.3949)
# ...
# Data collected for: 20.587118 N (20.5874 N) and -100.38414 E.(-100.3949)
# Data collected for: 20.585983 N (20.5874 N) and -100.40103 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58729 N (20.5874 N) and -100.38338 E.(-100.3949)
# Data collected for: 20.587553 N (20.5874 N) and -100.4026 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587553 N (20.5874 N) and -100.38814 E.(-100.3949)
# Data collected for: 20.586617 N (20.5874 N) and -100.38792 E.(-100.3949)
# Data collected for: 20.58725 N (20.5874 N) and -100.40706 E.(-100.3949)
# Data collected for: 20.586712 N (20.5874 N) and -100.42744 E.(-100.3949)
# Data collected for: 20.587412 N (20.5874 N) and -100.38697 E.(-100.3949)
# Data collected for: 20.587833 N (20.5874 N) and -100.40471 E.(-100.3949)
# Data collected for: 20.587519 N (20.5874 N) and -100.4109 E.(-100.3949)
# Data collected for: 20.588577 N (20.5874 N) and -100.38861 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586952 N (20.5874 N) and -100.41871 E.(-100.3949)
# Data collected for: 20.590471 N (20.5874 N) and -100.378365 E.(-100.3949)
# Data collected for: 20.587627 N (20.5874 N) and -100.39841 E.(-100.3949)
# Data collected for: 20.591177 N (20.5874 N) and -100.41029 E.(-100.3949)
# Data collected for: 20.587343 N (20.5874 N) and -100.39955 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587566 N (20.5874 N) and -100.3846 E.(-100.3949)
# Data collected for: 20.587355 N (20.5874 N) and -100.423325 E.(-100.3949)
# Data collected for: 20.58653 N (20.5874 N) and -100.42213 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586409 N (20.5874 N) and -100.43047 E.(-100.3949)
# Data collected for: 20.587378 N (20.5874 N) and -100.40751 E.(-100.3949)
# Data collected for: 20.587948 N (20.5874 N) and -100.40705 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58753 N (20.5874 N) and -100.40101 E.(-100.3949)
# Data collected for: 20.58286 N (20.5874 N) and -100.429436 E.(-100.3949)
# Data collected for: 20.587328 N (20.5874 N) and -100.38867 E.(-100.3949)
# Data collected for: 20.588133 N (20.5874 N) and -100.407616 E.(-100.3949)
# Data collected for: 20.589441 N (20.5874 N) and -100.368454 E.(-100.3949)
# Data collected for: 20.586512 N (20.5874 N) and -100.42717 E.(-100.3949)
# Data collected for: 20.587555 N (20.5874 N) and -100.3827 E.(-100.3949)
# Data collected for: 20.587261 N (20.5874 N) and -100.42845 E.(-100.3949)
# Data collected for: 20.5879 N (20.5874 N) and -100.36504 E.(-100.3949)
# Data collected for: 20.589426 N (20.5874 N) and -100.37488 E.(-100.3949)
# Data collected for: 20.58727 N (20.5874 N) and -100.395905 E.(-100.3949)
# Data collected for: 20.589825 N (20.5874 N) and -100.36051 E.(-100.3949)
# Data collected for: 20.587133 N (20.5874 N) and -100.40663 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587585 N (20.5874 N) and -100.43147 E.(-100.3949)
# Data collected for: 20.586958 N (20.5874 N) and -100.409134 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.584932 N (20.5874 N) and -100.41418 E.(-100.3949)
# Data collected for: 20.587393 N (20.5874 N) and -100.40846 E.(-100.3949)
# Data collected for: 20.587555 N (20.5874 N) and -100.40142 E.(-100.3949)
# Data collected for: 20.587667 N (20.5874 N) and -100.3983 E.(-100.3949)
# Data collected for: 20.587719 N (20.5874 N) and -100.36489 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58782 N (20.5874 N) and -100.37958 E.(-100.3949)
# Data collected for: 20.587399 N (20.5874 N) and -100.39427 E.(-100.3949)
# Data collected for: 20.587284 N (20.5874 N) and -100.3964 E.(-100.3949)
# Data collected for: 20.588297 N (20.5874 N) and -100.37902 E.(-100.3949)
# Data collected for: 20.588587 N (20.5874 N) and -100.37988 E.(-100.3949)
# Data collected for: 20.587395 N (20.5874 N) and -100.396034 E.(-100.3949)
# Data collected for: 20.587482 N (20.5874 N) and -100.39167 E.(-100.3949)
# Data collected for: 20.587688 N (20.5874 N) and -100.39675 E.(-100.3949)
# Data collected for: 20.587404 N (20.5874 N) and -100.380585 E.(-100.3949)
# Data collected for: 20.58692 N (20.5874 N) and -100.3862 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.5878 N (20.5874 N) and -100.39863 E.(-100.3949)
# Data collected for: 20.587261 N (20.5874 N) and -100.38287 E.(-100.3949)
# Data collected for: 20.58626 N (20.5874 N) and -100.420845 E.(-100.3949)
# Data collected for: 20.589867 N (20.5874 N) and -100.42583 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586681 N (20.5874 N) and -100.39073 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58749 N (20.5874 N) and -100.40595 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587069 N (20.5874 N) and -100.367714 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587074 N (20.5874 N) and -100.40097 E.(-100.3949)
# Data collected for: 20.587456 N (20.5874 N) and -100.379715 E.(-100.3949)
# Data collected for: 20.587334 N (20.5874 N) and -100.3878 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586828 N (20.5874 N) and -100.43854 E.(-100.3949)
# Data collected for: 20.588137 N (20.5874 N) and -100.37488 E.(-100.3949)
# Data collected for: 20.587091 N (20.5874 N) and -100.38125 E.(-100.3949)
# Data collected for: 20.586996 N (20.5874 N) and -100.409966 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58725 N (20.5874 N) and -100.42589 E.(-100.3949)
# Data collected for: 20.586164 N (20.5874 N) and -100.38873 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.585535 N (20.5874 N) and -100.406425 E.(-100.3949)
# Data collected for: 20.588287 N (20.5874 N) and -100.39744 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586472 N (20.5874 N) and -100.39679 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587244 N (20.5874 N) and -100.38661 E.(-100.3949)
# Data collected for: 20.587961 N (20.5874 N) and -100.406586 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58769 N (20.5874 N) and -100.36796 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587412 N (20.5874 N) and -100.38315 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587143 N (20.5874 N) and -100.40288 E.(-100.3949)
# Data collected for: 20.586157 N (20.5874 N) and -100.385025 E.(-100.3949)
# Data collected for: 20.588013 N (20.5874 N) and -100.40527 E.(-100.3949)
# Data collected for: 20.587122 N (20.5874 N) and -100.39561 E.(-100.3949)
# Data collected for: 20.588545 N (20.5874 N) and -100.40059 E.(-100.3949)
# Data collected for: 20.589314 N (20.5874 N) and -100.42037 E.(-100.3949)
# Data collected for: 20.586967 N (20.5874 N) and -100.389 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587547 N (20.5874 N) and -100.392784 E.(-100.3949)
# Data collected for: 20.586578 N (20.5874 N) and -100.40429 E.(-100.3949)
# Data collected for: 20.587173 N (20.5874 N) and -100.401436 E.(-100.3949)
# Data collected for: 20.591007 N (20.5874 N) and -100.40231 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587648 N (20.5874 N) and -100.40221 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588047 N (20.5874 N) and -100.394745 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58577 N (20.5874 N) and -100.416565 E.(-100.3949)
# Data collected for: 20.587032 N (20.5874 N) and -100.3812 E.(-100.3949)
# Data collected for: 20.58659 N (20.5874 N) and -100.3692 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587555 N (20.5874 N) and -100.394615 E.(-100.3949)
# Data collected for: 20.586056 N (20.5874 N) and -100.40008 E.(-100.3949)
# Data collected for: 20.586443 N (20.5874 N) and -100.37234 E.(-100.3949)
# Data collected for: 20.586718 N (20.5874 N) and -100.37778 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587027 N (20.5874 N) and -100.40664 E.(-100.3949)
# Data collected for: 20.583744 N (20.5874 N) and -100.36399 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587439 N (20.5874 N) and -100.41125 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586632 N (20.5874 N) and -100.36036 E.(-100.3949)
# Data collected for: 20.587017 N (20.5874 N) and -100.397026 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587885 N (20.5874 N) and -100.40237 E.(-100.3949)
# Data collected for: 20.58781 N (20.5874 N) and -100.406975 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.590418 N (20.5874 N) and -100.37625 E.(-100.3949)
# Data collected for: 20.587145 N (20.5874 N) and -100.38362 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587025 N (20.5874 N) and -100.377754 E.(-100.3949)
# Data collected for: 20.586802 N (20.5874 N) and -100.3883 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587523 N (20.5874 N) and -100.387794 E.(-100.3949)
# Data collected for: 20.587746 N (20.5874 N) and -100.35993 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586464 N (20.5874 N) and -100.40913 E.(-100.3949)
# Data collected for: 20.587803 N (20.5874 N) and -100.38454 E.(-100.3949)
# Data collected for: 20.58722 N (20.5874 N) and -100.41173 E.(-100.3949)
# Data collected for: 20.587559 N (20.5874 N) and -100.403786 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588367 N (20.5874 N) and -100.41337 E.(-100.3949)
# Data collected for: 20.587914 N (20.5874 N) and -100.40284 E.(-100.3949)
# Data collected for: 20.587715 N (20.5874 N) and -100.40911 E.(-100.3949)
# Data collected for: 20.588755 N (20.5874 N) and -100.37515 E.(-100.3949)
# Data collected for: 20.587946 N (20.5874 N) and -100.38777 E.(-100.3949)
# Data collected for: 20.587204 N (20.5874 N) and -100.38223 E.(-100.3949)
# Data collected for: 20.587284 N (20.5874 N) and -100.37805 E.(-100.3949)
# Data collected for: 20.586985 N (20.5874 N) and -100.406425 E.(-100.3949)
# Data collected for: 20.585901 N (20.5874 N) and -100.37086 E.(-100.3949)
# Data collected for: 20.586853 N (20.5874 N) and -100.4139 E.(-100.3949)
# Data collected for: 20.58666 N (20.5874 N) and -100.37762 E.(-100.3949)
# Data collected for: 20.586823 N (20.5874 N) and -100.4091 E.(-100.3949)
# Data collected for: 20.586905 N (20.5874 N) and -100.403275 E.(-100.3949)
# Data collected for: 20.58695 N (20.5874 N) and -100.398094 E.(-100.3949)
# Data collected for: 20.586506 N (20.5874 N) and -100.41165 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587337 N (20.5874 N) and -100.38498 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587975 N (20.5874 N) and -100.39654 E.(-100.3949)
# Data collected for: 20.58964 N (20.5874 N) and -100.357956 E.(-100.3949)
# Data collected for: 20.58708 N (20.5874 N) and -100.38054 E.(-100.3949)
# Data collected for: 20.588879 N (20.5874 N) and -100.42665 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58744 N (20.5874 N) and -100.395355 E.(-100.3949)
# Data collected for: 20.587654 N (20.5874 N) and -100.390205 E.(-100.3949)
# Data collected for: 20.586657 N (20.5874 N) and -100.36299 E.(-100.3949)
# Data collected for: 20.5871 N (20.5874 N) and -100.38531 E.(-100.3949)
# Data collected for: 20.586557 N (20.5874 N) and -100.39607 E.(-100.3949)
# Data collected for: 20.588749 N (20.5874 N) and -100.42694 E.(-100.3949)
# Data collected for: 20.58793 N (20.5874 N) and -100.38399 E.(-100.3949)
# Data collected for: 20.58672 N (20.5874 N) and -100.3751 E.(-100.3949)
# Data collected for: 20.588982 N (20.5874 N) and -100.385155 E.(-100.3949)
# Data collected for: 20.587965 N (20.5874 N) and -100.411095 E.(-100.3949)
# Data collected for: 20.587011 N (20.5874 N) and -100.40975 E.(-100.3949)
# Data collected for: 20.587896 N (20.5874 N) and -100.39033 E.(-100.3949)
# Data collected for: 20.58729 N (20.5874 N) and -100.390526 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588558 N (20.5874 N) and -100.41915 E.(-100.3949)
# Data collected for: 20.586836 N (20.5874 N) and -100.379974 E.(-100.3949)
# Data collected for: 20.589685 N (20.5874 N) and -100.416046 E.(-100.3949)
# Data collected for: 20.588942 N (20.5874 N) and -100.38369 E.(-100.3949)
# Data collected for: 20.588247 N (20.5874 N) and -100.40815 E.(-100.3949)
# Data collected for: 20.586954 N (20.5874 N) and -100.38645 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586988 N (20.5874 N) and -100.38704 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58747 N (20.5874 N) and -100.40665 E.(-100.3949)
# Data collected for: 20.587751 N (20.5874 N) and -100.38016 E.(-100.3949)
# Data collected for: 20.586983 N (20.5874 N) and -100.404625 E.(-100.3949)
# Data collected for: 20.58665 N (20.5874 N) and -100.40003 E.(-100.3949)
# Data collected for: 20.588028 N (20.5874 N) and -100.38455 E.(-100.3949)
# Data collected for: 20.586756 N (20.5874 N) and -100.390335 E.(-100.3949)
# Data collected for: 20.586723 N (20.5874 N) and -100.40938 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587973 N (20.5874 N) and -100.410286 E.(-100.3949)
# Data collected for: 20.587122 N (20.5874 N) and -100.40581 E.(-100.3949)
# Data collected for: 20.587221 N (20.5874 N) and -100.38995 E.(-100.3949)
# Data collected for: 20.589401 N (20.5874 N) and -100.36837 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586779 N (20.5874 N) and -100.38054 E.(-100.3949)
# Data collected for: 20.5872 N (20.5874 N) and -100.41901 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.58721 N (20.5874 N) and -100.42597 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587318 N (20.5874 N) and -100.40868 E.(-100.3949)
# Data collected for: 20.587925 N (20.5874 N) and -100.38784 E.(-100.3949)
# Data collected for: 20.586872 N (20.5874 N) and -100.42501 E.(-100.3949)
# Data collected for: 20.58653 N (20.5874 N) and -100.38449 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.588156 N (20.5874 N) and -100.37301 E.(-100.3949)
# Data collected for: 20.587776 N (20.5874 N) and -100.38527 E.(-100.3949)
# Data collected for: 20.587477 N (20.5874 N) and -100.401855 E.(-100.3949)
# Data collected for: 20.587051 N (20.5874 N) and -100.40237 E.(-100.3949)
# Data collected for: 20.585642 N (20.5874 N) and -100.4208 E.(-100.3949)
# Data collected for: 20.588509 N (20.5874 N) and -100.39352 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.587797 N (20.5874 N) and -100.3961 E.(-100.3949)
# Latitude (32-bit floating-point) not found
# Data collected for: 20.586172 N (20.5874 N) and -100.390076 E.(-100.3949)

# %% [markdown]
# **Build data frame**

# %%
# build dataframe
final_list = pd.DataFrame()
final_list['File Name'] = pd.Series(file_names)
final_list['land_and_ocean'] = pd.Series(values_land_and_ocean)
# add latitude
final_list['Latitude'] = pd.Series(latitude)
final_list['Longitude'] = pd.Series(longitude)
# extract year, month and day.
final_list["julian_date"] = final_list["File Name"].apply(get_julian_date)
final_list["year"] = final_list["julian_date"].apply(get_year)  
final_list["month"] = final_list["julian_date"].apply(get_month)  
final_list["day"] = final_list["julian_date"].apply(get_day)

# drop rows with value 0.
final_list = final_list.query("land_and_ocean != 0")
final_list.to_csv("../processed/queretaro.csv")

# %%
print "Number of files with errors: ", len(errors)

# %%
final_list

# %% [markdown]
# ***
#
# In case you need to check out what datasets are contained in each file run the code block below.
#
# **Verify that a datasets inside .hdf file.**

# %%
# read hdf files from current directory
all_files = glob.glob('*.hdf')
file = gdal.Open(all_files[0])

#Lists all subdatasets of any one file
for path, desc in file.GetSubDatasets():
    print(desc)
